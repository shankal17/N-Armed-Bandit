# %% [markdown]
# # Policy Selection Comparision

# %%
# Imports
import os
import sys
import inspect

sys.path.append('../scripts')

from agents import EpsilonGreedyAgent, SoftmaxAgent, UCBAgent
from bandit_machine import NArmedBanditMachine
from simulation import AgentComparision

# %%
# Initialize bandit, agents, and comparison
bandit = NArmedBanditMachine(10)
agents = [EpsilonGreedyAgent(0.1, description="0.1 $\epsilon$-Greedy"),\
          SoftmaxAgent(0.25, description="0.25 Temp Softmax"),
          EpsilonGreedyAgent(0.0, initial_estimate=5, description="Optimistic, Greedy\n$Q_0=5,\;\epsilon=0$"),
         UCBAgent(1, description="c=1 UCB Policy")]
comparison = AgentComparision(agents, bandit)

# %%
# Run Comparison
fig, axs = comparison.run_comparison(num_trials=2000, num_decisions=1000)
fig.set_size_inches(14, 10)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2000/2000 [02:59<00:00, 11.13it/s]
